# %%
from simpsom_dask.neighborhoods import Neighborhoods
from simpsom_dask.plots import plot_map
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload module is not an IPython extension.
# UsageError: Line magic function `%autoreload` not found.

# %%
from matplotlib.colors import BoundaryNorm


nei = Neighborhoods(4, 4, "hexagons", "grid", True)
coords = nei.coordinates
plot_map(coords, np.arange(16), np.arange(16, 32), norm=BoundaryNorm(np.arange(0, 40, 6), 256))
# Out:
# (<Figure size 500x400 with 2 Axes>, <Axes: >)
